# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import re
from scipy.stats.mstats import winsorize
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, accuracy_score
from sklearn.ensemble import RandomForestClassifier
from lightgbm import LGBMClassifier
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.metrics import confusion_matrix, roc_curve, auc, precision_recall_curve
import pickle

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
BASE_FILE_PATH = '/content/drive/MyDrive/Colab Notebooks/Final Project'
print(os.listdir(BASE_FILE_PATH))
# Out:
# ['Keys', 'Setting up connection with Git-Hub.ipynb', 'entries.csv', 'summoner_details.csv', 'updated_dataset.csv', 'filtered_dataset.csv', 'filtered_dataset.gsheet', 'filtered_+30_matches_dataset.csv', 'EDA.ipynb', 'merged_dataset.csv', 'Merging match with entries and classifying accounts.ipynb', 'merged_dataset.gsheet', 'Feature engineering and cleaning vol 1.ipynb', 'dataset_after_normalization.csv', 'keepign only win feature .ipynb', 'Models without data normalization.ipynb', 'Normalization_Parameters.csv', 'Normalization_Parameters_by_Game_Mode.csv', 'summoner_ids_used_in_model.csv', 'Normalization_Parameters_by_Team_Position.csv', 'gbm_model.pkl']

# %%
#get datasets
all_values_df = pd.read_csv(os.path.join(BASE_FILE_PATH, 'merged_dataset.csv'))
summoners_used_in_model = pd.read_csv(os.path.join(BASE_FILE_PATH, 'summoner_ids_used_in_model.csv'))
normalization_by_game_df = pd.read_csv(os.path.join(BASE_FILE_PATH, 'Normalization_Parameters_by_Game_Mode.csv'))
normalization_by_team_position_df = pd.read_csv(os.path.join(BASE_FILE_PATH, 'Normalization_Parameters_by_Team_Position.csv'))

# %%
#Open the pkl gbm_model that is in the BASE_FILE_PATH directory

with open(os.path.join(BASE_FILE_PATH, 'gbm_model.pkl'), 'rb') as f:
    gbm_model = pickle.load(f)

# %%
all_values_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128021 entries, 0 to 128020
# Data columns (total 27 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   match_id              128021 non-null  object
#  1   game_creation         128021 non-null  int64
#  2   game_duration         128021 non-null  int64
#  3   game_mode             128021 non-null  object
#  4   game_version          128021 non-null  object
#  5   map_id                128021 non-null  int64
#  6   summoner_id           128021 non-null  object
#  7   puuid                 128021 non-null  object
#  8   champion_id           128021 non-null  int64
#  9   kills                 128021 non-null  int64
#  10  deaths                128021 non-null  int64
#  11  assists               128021 non-null  int64
#  12  total_damage_dealt    128021 non-null  int64
#  13  total_damage_taken    128021 non-null  int64
#  14  gold_earned           128021 non-null  int64
#  15  vision_score          128021 non-null  int64
#  16  total_minions_killed  128021 non-null  int64
#  17  team_position         128021 non-null  object
#  18  win                   128021 non-null  bool
#  19  game_duration_min     128021 non-null  float64
#  20  game_creation_dt      128021 non-null  object
#  21  time_segment          128021 non-null  object
#  22  tier                  128021 non-null  object
#  23  rank                  128021 non-null  object
#  24  days_since_last_game  128021 non-null  int64
#  25  time_group            128021 non-null  object
#  26  binary_time_group     128021 non-null  object
# dtypes: bool(1), float64(1), int64(13), object(12)
# memory usage: 25.5+ MB

# %%
#remove from main dataset all information related to summoners that were used to train the model
filtered_df = all_values_df[~all_values_df['summoner_id'].isin(summoners_used_in_model['summoner_id'])]

# %%
#drop unnecessary columns
filtered_df.drop(columns=['match_id', 'game_creation','days_since_last_game',
                            'game_duration_min', 'win','puuid','map_id','champion_id',
                            'vision_score', 'game_version', 'tier', 'rank',
                            'time_group', 'team_position', 'time_segment'], inplace=True)
# Out:
# <ipython-input-176-286d60c22e09>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.drop(columns=['match_id', 'game_creation','days_since_last_game',

# %%
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 71587 entries, 0 to 127961
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   game_duration         71587 non-null  int64
#  1   game_mode             71587 non-null  object
#  2   summoner_id           71587 non-null  object
#  3   kills                 71587 non-null  int64
#  4   deaths                71587 non-null  int64
#  5   assists               71587 non-null  int64
#  6   total_damage_dealt    71587 non-null  int64
#  7   total_damage_taken    71587 non-null  int64
#  8   gold_earned           71587 non-null  int64
#  9   total_minions_killed  71587 non-null  int64
#  10  game_creation_dt      71587 non-null  object
#  11  binary_time_group     71587 non-null  object
# dtypes: int64(8), object(4)
# memory usage: 7.1+ MB

# %%
#get_dummies for game_mode
dummies = pd.get_dummies(filtered_df['game_mode'], prefix='game_mode')

#add dummies back to df
filtered_df = pd.concat([filtered_df, dummies], axis=1)

#drop original game_mode column
filtered_df = filtered_df.drop('game_mode', axis=1)

# %%
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 71587 entries, 0 to 127961
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   game_duration         71587 non-null  int64
#  1   summoner_id           71587 non-null  object
#  2   kills                 71587 non-null  int64
#  3   deaths                71587 non-null  int64
#  4   assists               71587 non-null  int64
#  5   total_damage_dealt    71587 non-null  int64
#  6   total_damage_taken    71587 non-null  int64
#  7   gold_earned           71587 non-null  int64
#  8   total_minions_killed  71587 non-null  int64
#  9   game_creation_dt      71587 non-null  object
#  10  binary_time_group     71587 non-null  object
#  11  game_mode_ARAM        71587 non-null  bool
#  12  game_mode_CHERRY      71587 non-null  bool
#  13  game_mode_CLASSIC     71587 non-null  bool
# dtypes: bool(3), int64(8), object(3)
# memory usage: 6.8+ MB

# %%
# Winsorizing features for CHERRY Game Mode
df_cherry = filtered_df[filtered_df['game_mode_CHERRY'] == True].copy()
features_to_winsorize = [
    'kills', 'deaths', 'assists', 'gold_earned', 'game_duration',
    'total_damage_dealt', 'total_damage_taken', 'total_minions_killed'
]

for feature in features_to_winsorize:
    # Apply winsorization
    df_cherry[f'{feature}_winsorized'] = winsorize(df_cherry[feature], limits=[0.01, 0.01])

# Update the main DataFrame only for CHERRY game mode rows
for feature in features_to_winsorize:
    filtered_df.loc[filtered_df['game_mode_CHERRY'], feature] = df_cherry[f'{feature}_winsorized']

# %%
# Normalize the features for each game mode separately
for index, row in normalization_by_game_df.iterrows():
    feature = row['Feature']
    game_mode = row['Game_Mode']
    mean_val = row['Mean']
    stddev_val = row['StdDev']

    # Check if the feature is in the list to be normalized and prepare normalized column name
    if feature in features_to_winsorize:
        normalized_feature_column = f'{feature}_normalized'
        # Normalize the feature in filtered_df where the game mode column is True
        if filtered_df[game_mode].any():  # Ensure there are rows to normalize for the game mode
            filtered_df.loc[filtered_df[game_mode], normalized_feature_column] = \
                (filtered_df.loc[filtered_df[game_mode], feature] - mean_val) / stddev_val

# %%
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 71587 entries, 0 to 127961
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   game_duration                    71587 non-null  int64
#  1   summoner_id                      71587 non-null  object
#  2   kills                            71587 non-null  int64
#  3   deaths                           71587 non-null  int64
#  4   assists                          71587 non-null  int64
#  5   total_damage_dealt               71587 non-null  int64
#  6   total_damage_taken               71587 non-null  int64
#  7   gold_earned                      71587 non-null  int64
#  8   total_minions_killed             71587 non-null  int64
#  9   game_creation_dt                 71587 non-null  object
#  10  binary_time_group                71587 non-null  object
#  11  game_mode_ARAM                   71587 non-null  bool
#  12  game_mode_CHERRY                 71587 non-null  bool
#  13  game_mode_CLASSIC                71587 non-null  bool
#  14  kills_normalized                 71587 non-null  float64
#  15  deaths_normalized                71587 non-null  float64
#  16  assists_normalized               71587 non-null  float64
#  17  gold_earned_normalized           71587 non-null  float64
#  18  game_duration_normalized         71587 non-null  float64
#  19  total_damage_dealt_normalized    71587 non-null  float64
#  20  total_damage_taken_normalized    71587 non-null  float64
#  21  total_minions_killed_normalized  71587 non-null  float64
# dtypes: bool(3), float64(8), int64(8), object(3)
# memory usage: 11.1+ MB

# %%
filtered_df['game_creation_dt'] = pd.to_datetime(filtered_df['game_creation_dt'])

# Define bins based on quantiles
quantiles = filtered_df['game_creation_dt'].quantile([0, 0.33, 0.67, 1]).to_list()
filtered_df['time_segment'] = pd.cut(filtered_df['game_creation_dt'], bins=quantiles, labels=['initial', 'mid', 'late'], include_lowest=True)

# %%
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 71587 entries, 0 to 127961
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   game_duration                    71587 non-null  int64
#  1   summoner_id                      71587 non-null  object
#  2   kills                            71587 non-null  int64
#  3   deaths                           71587 non-null  int64
#  4   assists                          71587 non-null  int64
#  5   total_damage_dealt               71587 non-null  int64
#  6   total_damage_taken               71587 non-null  int64
#  7   gold_earned                      71587 non-null  int64
#  8   total_minions_killed             71587 non-null  int64
#  9   game_creation_dt                 71587 non-null  datetime64[ns]
#  10  binary_time_group                71587 non-null  object
#  11  game_mode_ARAM                   71587 non-null  bool
#  12  game_mode_CHERRY                 71587 non-null  bool
#  13  game_mode_CLASSIC                71587 non-null  bool
#  14  kills_normalized                 71587 non-null  float64
#  15  deaths_normalized                71587 non-null  float64
#  16  assists_normalized               71587 non-null  float64
#  17  gold_earned_normalized           71587 non-null  float64
#  18  game_duration_normalized         71587 non-null  float64
#  19  total_damage_dealt_normalized    71587 non-null  float64
#  20  total_damage_taken_normalized    71587 non-null  float64
#  21  total_minions_killed_normalized  71587 non-null  float64
#  22  time_segment                     71587 non-null  category
# dtypes: bool(3), category(1), datetime64[ns](1), float64(8), int64(8), object(2)
# memory usage: 11.2+ MB

# %%
filtered_df.drop(columns=['game_creation_dt', 'game_duration', 'kills', 'deaths',
                          'assists', 'total_damage_dealt', 'total_damage_taken',
                          'gold_earned', 'total_minions_killed', 'game_mode_ARAM',
                          'game_mode_CHERRY', 'game_mode_CLASSIC'], inplace=True)

# %%
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 71587 entries, 0 to 127961
# Data columns (total 11 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   summoner_id                      71587 non-null  object
#  1   binary_time_group                71587 non-null  object
#  2   kills_normalized                 71587 non-null  float64
#  3   deaths_normalized                71587 non-null  float64
#  4   assists_normalized               71587 non-null  float64
#  5   gold_earned_normalized           71587 non-null  float64
#  6   game_duration_normalized         71587 non-null  float64
#  7   total_damage_dealt_normalized    71587 non-null  float64
#  8   total_damage_taken_normalized    71587 non-null  float64
#  9   total_minions_killed_normalized  71587 non-null  float64
#  10  time_segment                     71587 non-null  category
# dtypes: category(1), float64(8), object(2)
# memory usage: 6.1+ MB

# %%
# Exclude non-numeric columns from the DataFrame before grouping
numeric_cols = filtered_df.select_dtypes(include=[np.number])  # This selects only numeric columns
df_numeric = filtered_df[['summoner_id', 'time_segment'] + list(numeric_cols.columns)]

# Addressing the FutureWarning by setting observed=True if the DataFrame contains any categorical data
grouped_df = df_numeric.groupby(['summoner_id', 'time_segment'], observed=True).mean()

# Pivoting the data so each 'time_segment' becomes a column
pivot_df = grouped_df.unstack(level='time_segment')

# Flattening the columns to make them more manageable
pivot_df.columns = ['_'.join(col).strip() for col in pivot_df.columns.values]

# Resetting the index so 'summoner_id' becomes a column
pivot_df.reset_index(inplace=True)

# Optionally, fill any NaN values that may arise from empty segments
pivot_df.fillna(0, inplace=True)

# Display the first few rows to verify
print(pivot_df.head())
# Out:
#                                         summoner_id  kills_normalized_initial  \
# 0  --yDuIIktIqjdme32tV29wcBIFPE08CY8WhiZhL4Gd6p60aE                 -0.678147
# 1  -0FAl-E5gzHW35MsMHI7ZBv4jCme6S8TT2W7az4-G7x7Y-Yy                 -0.203322
# 2   -3ntNAfsqQ8f8pHSCh805dnhlQvmv2_GYLWxhwDfn6I1h2g                  0.340567
# 3   -57abaqo0rKW30x3I3SoJuDtkU0-vqFOXNNhomuF3lbHj-g                  0.165148
# 4  -D7G5Q31odyA5MB6rDTvKJwiCLr-iWHmV55cAr9jOLVyEh60                  0.000000
#
#    kills_normalized_mid  kills_normalized_late  deaths_normalized_initial  \
# 0             -0.265878              -0.471296                  -1.383072
# 1             -0.583182              -0.062466                  -0.511505
# 2              1.019350               0.000000                  -0.049310
# 3             -0.091400              -0.171668                  -0.313471
# 4              0.105556               0.480615                   0.000000
#
#    deaths_normalized_mid  deaths_normalized_late  assists_normalized_initial  \
# 0               0.700555                0.075005                   -0.420678
# 1              -0.511505                0.143827                   -0.068459
# 2               0.469008                0.000000                    0.027600
# 3              -0.003091                0.747426                   -0.500725
# 4               0.023442                0.033162                    0.000000
#
#    assists_normalized_mid  assists_normalized_late  ...  \
# 0                0.377182                 0.637237  ...
# 1                0.724032                -0.100231  ...
# 2                0.404834                 0.000000  ...
# 3               -0.178527                 0.107650  ...
# 4                0.058769                -0.193876  ...
#
#    game_duration_normalized_late  total_damage_dealt_normalized_initial  \
# 0                      -0.089314                              -1.324098
# 1                      -0.021251                               0.396154
# 2                       0.000000                              -0.203626
# 3                       0.516975                              -0.183752
# 4                       0.070437                               0.000000
#
#    total_damage_dealt_normalized_mid  total_damage_dealt_normalized_late  \
# 0                          -0.012895                           -0.455190
# 1                           0.323028                            0.150008
# 2                          -0.071188                            0.000000
# 3                          -0.009379                            0.130955
# 4                           0.241060                            0.623436
#
#    total_damage_taken_normalized_initial  total_damage_taken_normalized_mid  \
# 0                              -1.407530                           0.062870
# 1                               0.420045                           0.507005
# 2                              -0.325029                           0.189898
# 3                              -0.550573                          -0.355352
# 4                               0.000000                          -0.249856
#
#    total_damage_taken_normalized_late  \
# 0                           -0.338132
# 1                            0.202774
# 2                            0.000000
# 3                           -0.128103
# 4                           -0.127411
#
#    total_minions_killed_normalized_initial  \
# 0                                -1.025501
# 1                                -0.993512
# 2                                -0.253806
# 3                                 0.024180
# 4                                 0.000000
#
#    total_minions_killed_normalized_mid  total_minions_killed_normalized_late
# 0                            -0.101520                             -0.475314
# 1                            -1.124375                             -0.474935
# 2                             0.414719                              0.000000
# 3                             0.722455                              0.932598
# 4                             0.249850                              0.621858
#
# [5 rows x 25 columns]

# %%
# Extract binary_time_group and summoner_id, and drop duplicates
binary_time_mapping = filtered_df[['summoner_id', 'binary_time_group']].drop_duplicates()

# Merge this mapping into the pivot_df
pivot_df = pivot_df.merge(binary_time_mapping, on='summoner_id', how='left')

# Display the first few rows to verify the merge
print(pivot_df.head())
# Out:
#                                         summoner_id  kills_normalized_initial  \
# 0  --yDuIIktIqjdme32tV29wcBIFPE08CY8WhiZhL4Gd6p60aE                 -0.678147
# 1  -0FAl-E5gzHW35MsMHI7ZBv4jCme6S8TT2W7az4-G7x7Y-Yy                 -0.203322
# 2   -3ntNAfsqQ8f8pHSCh805dnhlQvmv2_GYLWxhwDfn6I1h2g                  0.340567
# 3   -57abaqo0rKW30x3I3SoJuDtkU0-vqFOXNNhomuF3lbHj-g                  0.165148
# 4  -D7G5Q31odyA5MB6rDTvKJwiCLr-iWHmV55cAr9jOLVyEh60                  0.000000
#
#    kills_normalized_mid  kills_normalized_late  deaths_normalized_initial  \
# 0             -0.265878              -0.471296                  -1.383072
# 1             -0.583182              -0.062466                  -0.511505
# 2              1.019350               0.000000                  -0.049310
# 3             -0.091400              -0.171668                  -0.313471
# 4              0.105556               0.480615                   0.000000
#
#    deaths_normalized_mid  deaths_normalized_late  assists_normalized_initial  \
# 0               0.700555                0.075005                   -0.420678
# 1              -0.511505                0.143827                   -0.068459
# 2               0.469008                0.000000                    0.027600
# 3              -0.003091                0.747426                   -0.500725
# 4               0.023442                0.033162                    0.000000
#
#    assists_normalized_mid  assists_normalized_late  ...  \
# 0                0.377182                 0.637237  ...
# 1                0.724032                -0.100231  ...
# 2                0.404834                 0.000000  ...
# 3               -0.178527                 0.107650  ...
# 4                0.058769                -0.193876  ...
#
#    total_damage_dealt_normalized_initial  total_damage_dealt_normalized_mid  \
# 0                              -1.324098                          -0.012895
# 1                               0.396154                           0.323028
# 2                              -0.203626                          -0.071188
# 3                              -0.183752                          -0.009379
# 4                               0.000000                           0.241060
#
#    total_damage_dealt_normalized_late  total_damage_taken_normalized_initial  \
# 0                           -0.455190                              -1.407530
# 1                            0.150008                               0.420045
# 2                            0.000000                              -0.325029
# 3                            0.130955                              -0.550573
# 4                            0.623436                               0.000000
#
#    total_damage_taken_normalized_mid  total_damage_taken_normalized_late  \
# 0                           0.062870                           -0.338132
# 1                           0.507005                            0.202774
# 2                           0.189898                            0.000000
# 3                          -0.355352                           -0.128103
# 4                          -0.249856                           -0.127411
#
#    total_minions_killed_normalized_initial  \
# 0                                -1.025501
# 1                                -0.993512
# 2                                -0.253806
# 3                                 0.024180
# 4                                 0.000000
#
#    total_minions_killed_normalized_mid  total_minions_killed_normalized_late  \
# 0                            -0.101520                             -0.475314
# 1                            -1.124375                             -0.474935
# 2                             0.414719                              0.000000
# 3                             0.722455                              0.932598
# 4                             0.249850                              0.621858
#
#    binary_time_group
# 0             Active
# 1             Active
# 2           Inactive
# 3             Active
# 4             Active
#
# [5 rows x 26 columns]

# %%
pivot_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1274 entries, 0 to 1273
# Data columns (total 26 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   summoner_id                              1274 non-null   object
#  1   kills_normalized_initial                 1274 non-null   float64
#  2   kills_normalized_mid                     1274 non-null   float64
#  3   kills_normalized_late                    1274 non-null   float64
#  4   deaths_normalized_initial                1274 non-null   float64
#  5   deaths_normalized_mid                    1274 non-null   float64
#  6   deaths_normalized_late                   1274 non-null   float64
#  7   assists_normalized_initial               1274 non-null   float64
#  8   assists_normalized_mid                   1274 non-null   float64
#  9   assists_normalized_late                  1274 non-null   float64
#  10  gold_earned_normalized_initial           1274 non-null   float64
#  11  gold_earned_normalized_mid               1274 non-null   float64
#  12  gold_earned_normalized_late              1274 non-null   float64
#  13  game_duration_normalized_initial         1274 non-null   float64
#  14  game_duration_normalized_mid             1274 non-null   float64
#  15  game_duration_normalized_late            1274 non-null   float64
#  16  total_damage_dealt_normalized_initial    1274 non-null   float64
#  17  total_damage_dealt_normalized_mid        1274 non-null   float64
#  18  total_damage_dealt_normalized_late       1274 non-null   float64
#  19  total_damage_taken_normalized_initial    1274 non-null   float64
#  20  total_damage_taken_normalized_mid        1274 non-null   float64
#  21  total_damage_taken_normalized_late       1274 non-null   float64
#  22  total_minions_killed_normalized_initial  1274 non-null   float64
#  23  total_minions_killed_normalized_mid      1274 non-null   float64
#  24  total_minions_killed_normalized_late     1274 non-null   float64
#  25  binary_time_group                        1274 non-null   object
# dtypes: float64(24), object(2)
# memory usage: 258.9+ KB

# %%
#selecting top20 most important features
top_features = [
    'deaths_normalized_late', 'kills_normalized_late', 'assists_normalized_late',
    'game_duration_normalized_late', 'total_minions_killed_normalized_late',
    'gold_earned_normalized_late', 'total_damage_dealt_normalized_late',
    'total_damage_taken_normalized_late', 'deaths_normalized_mid',
    'kills_normalized_mid', 'assists_normalized_mid', 'game_duration_normalized_mid',
    'total_minions_killed_normalized_mid', 'gold_earned_normalized_mid',
    'total_damage_dealt_normalized_mid', 'total_damage_taken_normalized_mid',
    'deaths_normalized_initial', 'kills_normalized_initial', 'assists_normalized_initial',
    'game_duration_normalized_initial'
]


# Creating a new DataFrame that includes only the top features and the target variable
top_features_df = pivot_df[top_features + ['binary_time_group']+['summoner_id']]

# %%
top_features_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1274 entries, 0 to 1273
# Data columns (total 22 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   deaths_normalized_late                1274 non-null   float64
#  1   kills_normalized_late                 1274 non-null   float64
#  2   assists_normalized_late               1274 non-null   float64
#  3   game_duration_normalized_late         1274 non-null   float64
#  4   total_minions_killed_normalized_late  1274 non-null   float64
#  5   gold_earned_normalized_late           1274 non-null   float64
#  6   total_damage_dealt_normalized_late    1274 non-null   float64
#  7   total_damage_taken_normalized_late    1274 non-null   float64
#  8   deaths_normalized_mid                 1274 non-null   float64
#  9   kills_normalized_mid                  1274 non-null   float64
#  10  assists_normalized_mid                1274 non-null   float64
#  11  game_duration_normalized_mid          1274 non-null   float64
#  12  total_minions_killed_normalized_mid   1274 non-null   float64
#  13  gold_earned_normalized_mid            1274 non-null   float64
#  14  total_damage_dealt_normalized_mid     1274 non-null   float64
#  15  total_damage_taken_normalized_mid     1274 non-null   float64
#  16  deaths_normalized_initial             1274 non-null   float64
#  17  kills_normalized_initial              1274 non-null   float64
#  18  assists_normalized_initial            1274 non-null   float64
#  19  game_duration_normalized_initial      1274 non-null   float64
#  20  binary_time_group                     1274 non-null   object
#  21  summoner_id                           1274 non-null   object
# dtypes: float64(20), object(2)
# memory usage: 219.1+ KB

# %%
def evaluate_predictions(df, model, features_col, actual_col='binary_time_group'):
    """
    Evaluates the model predictions against actual labels on a DataFrame.

    Args:
    df (DataFrame): The DataFrame containing the features and actual labels.
    model (Model): Trained machine learning model.
    features_col (list): List of columns to use as features.
    actual_col (str): Column name of the actual labels.

    Returns:
    Prints row-by-row prediction results and a summary of the evaluation.
    """
    # Extracting the features and actual labels
    X = df[features_col]
    y_actual = df[actual_col]

    # Predicting using the model
    predictions = model.predict(X)

    correct = 0
    print("Index\tActual\tPredicted\tCorrect")
    # Iterating through each prediction and actual label
    for i, (actual, pred) in enumerate(zip(y_actual, predictions)):
        correct_pred = 'Yes' if actual == pred else 'No'
        print(f"{i}\t{actual}\t{pred}\t{correct_pred}")
        if actual == pred:
            correct += 1

    total = len(predictions)
    print(f"\nTotal Correct Predictions: {correct}/{total}")
    print(f"Accuracy: {correct/total:.2f}")

# Prepare your dataframe by excluding non-feature columns
features_for_prediction = top_features_df.columns.difference(['binary_time_group', 'summoner_id'])
evaluate_predictions(top_features_df, gbm_model, features_for_prediction)
# Out:
# Index	Actual	Predicted	Correct
# 0	Active	Active	Yes
# 1	Active	Active	Yes
# 2	Inactive	Active	No
# 3	Active	Active	Yes
# 4	Active	Active	Yes
# 5	Active	Active	Yes
# 6	Inactive	Active	No
# 7	Active	Active	Yes
# 8	Active	Active	Yes
# 9	Active	Inactive	No
# 10	Active	Active	Yes
# 11	Active	Active	Yes
# 12	Active	Active	Yes
# 13	Active	Active	Yes
# 14	Active	Active	Yes
# 15	Inactive	Active	No
# 16	Active	Active	Yes
# 17	Active	Active	Yes
# 18	Active	Active	Yes
# 19	Inactive	Active	No
# 20	Inactive	Active	No
# 21	Active	Active	Yes
# 22	Inactive	Active	No
# 23	Active	Active	Yes
# 24	Active	Active	Yes
# 25	Inactive	Active	No
# 26	Inactive	Inactive	Yes
# 27	Inactive	Active	No
# 28	Active	Active	Yes
# 29	Active	Active	Yes
# 30	Active	Active	Yes
# 31	Active	Active	Yes
# 32	Active	Active	Yes
# 33	Inactive	Active	No
# 34	Active	Active	Yes
# 35	Active	Active	Yes
# 36	Inactive	Active	No
# 37	Inactive	Active	No
# 38	Inactive	Active	No
# 39	Active	Active	Yes
# 40	Inactive	Active	No
# 41	Active	Active	Yes
# 42	Inactive	Active	No
# 43	Active	Active	Yes
# 44	Inactive	Active	No
# 45	Inactive	Active	No
# 46	Active	Active	Yes
# 47	Inactive	Active	No
# 48	Active	Active	Yes
# 49	Inactive	Active	No
# 50	Active	Inactive	No
# 51	Active	Active	Yes
# 52	Active	Active	Yes
# 53	Inactive	Active	No
# 54	Inactive	Active	No
# 55	Active	Active	Yes
# 56	Inactive	Active	No
# 57	Inactive	Active	No
# 58	Inactive	Inactive	Yes
# 59	Inactive	Active	No
# 60	Inactive	Active	No
# 61	Inactive	Active	No
# 62	Active	Active	Yes
# 63	Active	Active	Yes
# 64	Active	Active	Yes
# 65	Inactive	Active	No
# 66	Inactive	Active	No
# 67	Inactive	Active	No
# 68	Active	Active	Yes
# 69	Inactive	Active	No
# 70	Active	Active	Yes
# 71	Inactive	Active	No
# 72	Active	Active	Yes
# 73	Active	Active	Yes
# 74	Inactive	Active	No
# 75	Active	Active	Yes
# 76	Inactive	Active	No
# 77	Active	Active	Yes
# 78	Active	Active	Yes
# 79	Inactive	Active	No
# 80	Active	Active	Yes
# 81	Inactive	Active	No
# 82	Inactive	Active	No
# 83	Active	Inactive	No
# 84	Active	Active	Yes
# 85	Inactive	Inactive	Yes
# 86	Inactive	Active	No
# 87	Active	Active	Yes
# 88	Inactive	Inactive	Yes
# 89	Inactive	Active	No
# 90	Active	Active	Yes
# 91	Inactive	Active	No
# 92	Active	Active	Yes
# 93	Active	Active	Yes
# 94	Active	Active	Yes
# 95	Active	Active	Yes
# 96	Active	Active	Yes
# 97	Inactive	Inactive	Yes
# 98	Active	Active	Yes
# 99	Active	Active	Yes
# 100	Inactive	Active	No
# 101	Inactive	Active	No
# 102	Active	Active	Yes
# 103	Active	Active	Yes
# 104	Active	Active	Yes
# 105	Inactive	Inactive	Yes
# 106	Active	Active	Yes
# 107	Active	Active	Yes
# 108	Inactive	Active	No
# 109	Inactive	Active	No
# 110	Inactive	Active	No
# 111	Active	Active	Yes
# 112	Active	Active	Yes
# 113	Inactive	Active	No
# 114	Active	Active	Yes
# 115	Inactive	Active	No
# 116	Inactive	Active	No
# 117	Inactive	Active	No
# 118	Inactive	Active	No
# 119	Inactive	Active	No
# 120	Active	Active	Yes
# 121	Inactive	Active	No
# 122	Inactive	Inactive	Yes
# 123	Inactive	Inactive	Yes
# 124	Active	Active	Yes
# 125	Inactive	Active	No
# 126	Active	Active	Yes
# 127	Active	Active	Yes
# 128	Inactive	Active	No
# 129	Active	Active	Yes
# 130	Active	Inactive	No
# 131	Active	Active	Yes
# 132	Inactive	Active	No
# 133	Active	Active	Yes
# 134	Inactive	Inactive	Yes
# 135	Active	Active	Yes
# 136	Active	Active	Yes
# 137	Inactive	Active	No
# 138	Inactive	Inactive	Yes
# 139	Inactive	Active	No
# 140	Inactive	Active	No
# 141	Inactive	Active	No
# 142	Inactive	Active	No
# 143	Inactive	Active	No
# 144	Active	Active	Yes
# 145	Inactive	Active	No
# 146	Inactive	Active	No
# 147	Active	Active	Yes
# 148	Inactive	Active	No
# 149	Inactive	Active	No
# 150	Active	Active	Yes
# 151	Inactive	Inactive	Yes
# 152	Active	Active	Yes
# 153	Active	Active	Yes
# 154	Active	Active	Yes
# 155	Active	Active	Yes
# 156	Active	Active	Yes
# 157	Active	Active	Yes
# 158	Active	Active	Yes
# 159	Inactive	Active	No
# 160	Active	Active	Yes
# 161	Inactive	Active	No
# 162	Active	Active	Yes
# 163	Active	Active	Yes
# 164	Active	Active	Yes
# 165	Active	Active	Yes
# 166	Inactive	Active	No
# 167	Inactive	Active	No
# 168	Inactive	Active	No
# 169	Inactive	Inactive	Yes
# 170	Active	Active	Yes
# 171	Inactive	Active	No
# 172	Inactive	Inactive	Yes
# 173	Active	Inactive	No
# 174	Inactive	Active	No
# 175	Active	Active	Yes
# 176	Active	Active	Yes
# 177	Inactive	Active	No
# 178	Active	Active	Yes
# 179	Inactive	Active	No
# 180	Active	Inactive	No
# 181	Active	Active	Yes
# 182	Active	Active	Yes
# 183	Active	Active	Yes
# 184	Inactive	Active	No
# 185	Active	Active	Yes
# 186	Inactive	Active	No
# 187	Active	Active	Yes
# 188	Inactive	Active	No
# 189	Inactive	Active	No
# 190	Inactive	Active	No
# 191	Active	Active	Yes
# 192	Inactive	Active	No
# 193	Active	Active	Yes
# 194	Inactive	Active	No
# 195	Active	Active	Yes
# 196	Active	Active	Yes
# 197	Inactive	Active	No
# 198	Active	Active	Yes
# 199	Active	Active	Yes
# 200	Inactive	Active	No
# 201	Active	Active	Yes
# 202	Inactive	Active	No
# 203	Active	Active	Yes
# 204	Inactive	Active	No
# 205	Active	Active	Yes
# 206	Active	Active	Yes
# 207	Inactive	Active	No
# 208	Active	Active	Yes
# 209	Active	Inactive	No
# 210	Active	Active	Yes
# 211	Inactive	Inactive	Yes
# 212	Active	Active	Yes
# 213	Active	Active	Yes
# 214	Inactive	Active	No
# 215	Active	Active	Yes
# 216	Inactive	Active	No
# 217	Active	Active	Yes
# 218	Inactive	Active	No
# 219	Inactive	Active	No
# 220	Active	Active	Yes
# 221	Inactive	Active	No
# 222	Active	Active	Yes
# 223	Inactive	Inactive	Yes
# 224	Inactive	Active	No
# 225	Active	Active	Yes
# 226	Inactive	Active	No
# 227	Inactive	Active	No
# 228	Active	Active	Yes
# 229	Active	Active	Yes
# 230	Inactive	Active	No
# 231	Active	Active	Yes
# 232	Inactive	Active	No
# 233	Inactive	Active	No
# 234	Active	Active	Yes
# 235	Inactive	Active	No
# 236	Inactive	Inactive	Yes
# 237	Inactive	Active	No
# 238	Active	Active	Yes
# 239	Active	Active	Yes
# 240	Inactive	Active	No
# 241	Inactive	Active	No
# 242	Inactive	Active	No
# 243	Inactive	Inactive	Yes
# 244	Inactive	Active	No
# 245	Inactive	Active	No
# 246	Inactive	Active	No
# 247	Active	Active	Yes
# 248	Active	Active	Yes
# 249	Active	Inactive	No
# 250	Active	Active	Yes
# 251	Active	Active	Yes
# 252	Inactive	Active	No
# 253	Active	Active	Yes
# 254	Active	Active	Yes
# 255	Active	Active	Yes
# 256	Inactive	Inactive	Yes
# 257	Inactive	Active	No
# 258	Active	Active	Yes
# 259	Active	Active	Yes
# 260	Inactive	Active	No
# 261	Active	Active	Yes
# 262	Active	Active	Yes
# 263	Inactive	Active	No
# 264	Active	Active	Yes
# 265	Active	Active	Yes
# 266	Active	Active	Yes
# 267	Inactive	Active	No
# 268	Inactive	Active	No
# 269	Inactive	Active	No
# 270	Inactive	Active	No
# 271	Inactive	Active	No
# 272	Inactive	Active	No
# 273	Inactive	Inactive	Yes
# 274	Inactive	Active	No
# 275	Inactive	Active	No
# 276	Active	Active	Yes
# 277	Active	Inactive	No
# 278	Inactive	Active	No
# 279	Inactive	Inactive	Yes
# 280	Inactive	Active	No
# 281	Active	Active	Yes
# 282	Active	Active	Yes
# 283	Inactive	Active	No
# 284	Inactive	Inactive	Yes
# 285	Inactive	Active	No
# 286	Inactive	Active	No
# 287	Inactive	Active	No
# 288	Inactive	Active	No
# 289	Active	Active	Yes
# 290	Inactive	Active	No
# 291	Active	Active	Yes
# 292	Inactive	Active	No
# 293	Active	Active	Yes
# 294	Inactive	Active	No
# 295	Active	Active	Yes
# 296	Active	Active	Yes
# 297	Active	Active	Yes
# 298	Inactive	Active	No
# 299	Inactive	Inactive	Yes
# 300	Active	Active	Yes
# 301	Active	Active	Yes
# 302	Active	Active	Yes
# 303	Inactive	Active	No
# 304	Active	Active	Yes
# 305	Inactive	Active	No
# 306	Active	Active	Yes
# 307	Active	Active	Yes
# 308	Inactive	Active	No
# 309	Active	Active	Yes
# 310	Active	Active	Yes
# 311	Inactive	Active	No
# 312	Inactive	Active	No
# 313	Inactive	Active	No
# 314	Active	Active	Yes
# 315	Inactive	Active	No
# 316	Active	Active	Yes
# 317	Active	Active	Yes
# 318	Inactive	Active	No
# 319	Inactive	Active	No
# 320	Active	Active	Yes
# 321	Active	Active	Yes
# 322	Active	Active	Yes
# 323	Inactive	Active	No
# 324	Inactive	Active	No
# 325	Inactive	Inactive	Yes
# 326	Active	Active	Yes
# 327	Inactive	Active	No
# 328	Active	Active	Yes
# 329	Inactive	Active	No
# 330	Inactive	Active	No
# 331	Inactive	Inactive	Yes
# 332	Active	Active	Yes
# 333	Inactive	Inactive	Yes
# 334	Active	Active	Yes
# 335	Active	Active	Yes
# 336	Active	Active	Yes
# 337	Inactive	Active	No
# 338	Inactive	Active	No
# 339	Inactive	Inactive	Yes
# 340	Active	Active	Yes
# 341	Inactive	Active	No
# 342	Inactive	Active	No
# 343	Active	Active	Yes
# 344	Active	Active	Yes
# 345	Inactive	Active	No
# 346	Active	Active	Yes
# 347	Inactive	Active	No
# 348	Inactive	Active	No
# 349	Active	Active	Yes
# 350	Inactive	Active	No
# 351	Inactive	Active	No
# 352	Active	Active	Yes
# 353	Active	Active	Yes
# 354	Active	Active	Yes
# 355	Active	Active	Yes
# 356	Inactive	Active	No
# 357	Inactive	Active	No
# 358	Active	Active	Yes
# 359	Active	Active	Yes
# 360	Inactive	Active	No
# 361	Inactive	Active	No
# 362	Active	Inactive	No
# 363	Active	Active	Yes
# 364	Inactive	Active	No
# 365	Inactive	Active	No
# 366	Inactive	Active	No
# 367	Inactive	Inactive	Yes
# 368	Inactive	Active	No
# 369	Inactive	Inactive	Yes
# 370	Active	Active	Yes
# 371	Active	Active	Yes
# 372	Active	Active	Yes
# 373	Inactive	Active	No
# 374	Inactive	Active	No
# 375	Inactive	Active	No
# 376	Inactive	Inactive	Yes
# 377	Inactive	Active	No
# 378	Active	Active	Yes
# 379	Active	Active	Yes
# 380	Active	Active	Yes
# 381	Inactive	Active	No
# 382	Active	Active	Yes
# 383	Active	Active	Yes
# 384	Active	Active	Yes
# 385	Inactive	Active	No
# 386	Active	Active	Yes
# 387	Inactive	Inactive	Yes
# 388	Active	Active	Yes
# 389	Inactive	Inactive	Yes
# 390	Inactive	Inactive	Yes
# 391	Inactive	Inactive	Yes
# 392	Inactive	Active	No
# 393	Active	Active	Yes
# 394	Inactive	Inactive	Yes
# 395	Active	Active	Yes
# 396	Inactive	Inactive	Yes
# 397	Active	Active	Yes
# 398	Inactive	Active	No
# 399	Inactive	Active	No
# 400	Inactive	Active	No
# 401	Inactive	Active	No
# 402	Active	Active	Yes
# 403	Inactive	Active	No
# 404	Active	Active	Yes
# 405	Inactive	Active	No
# 406	Active	Inactive	No
# 407	Active	Active	Yes
# 408	Inactive	Active	No
# 409	Inactive	Active	No
# 410	Inactive	Active	No
# 411	Active	Inactive	No
# 412	Inactive	Active	No
# 413	Active	Active	Yes
# 414	Active	Active	Yes
# 415	Inactive	Active	No
# 416	Active	Active	Yes
# 417	Inactive	Active	No
# 418	Active	Active	Yes
# 419	Inactive	Active	No
# 420	Inactive	Active	No
# 421	Inactive	Active	No
# 422	Active	Active	Yes
# 423	Active	Active	Yes
# 424	Inactive	Active	No
# 425	Active	Active	Yes
# 426	Inactive	Active	No
# 427	Active	Active	Yes
# 428	Inactive	Active	No
# 429	Inactive	Active	No
# 430	Active	Active	Yes
# 431	Inactive	Inactive	Yes
# 432	Inactive	Active	No
# 433	Inactive	Active	No
# 434	Inactive	Active	No
# 435	Active	Active	Yes
# 436	Inactive	Active	No
# 437	Active	Active	Yes
# 438	Active	Active	Yes
# 439	Active	Inactive	No
# 440	Active	Active	Yes
# 441	Active	Active	Yes
# 442	Inactive	Active	No
# 443	Active	Active	Yes
# 444	Active	Active	Yes
# 445	Inactive	Active	No
# 446	Active	Active	Yes
# 447	Inactive	Active	No
# 448	Active	Active	Yes
# 449	Active	Active	Yes
# 450	Inactive	Active	No
# 451	Inactive	Active	No
# 452	Inactive	Active	No
# 453	Active	Active	Yes
# 454	Active	Active	Yes
# 455	Active	Active	Yes
# 456	Inactive	Inactive	Yes
# 457	Active	Active	Yes
# 458	Inactive	Active	No
# 459	Active	Active	Yes
# 460	Inactive	Active	No
# 461	Active	Active	Yes
# 462	Active	Active	Yes
# 463	Active	Active	Yes
# 464	Active	Active	Yes
# 465	Inactive	Active	No
# 466	Active	Active	Yes
# 467	Active	Active	Yes
# 468	Active	Active	Yes
# 469	Inactive	Active	No
# 470	Active	Active	Yes
# 471	Inactive	Active	No
# 472	Inactive	Active	No
# 473	Inactive	Active	No
# 474	Active	Active	Yes
# 475	Active	Active	Yes
# 476	Active	Active	Yes
# 477	Active	Active	Yes
# 478	Inactive	Active	No
# 479	Active	Active	Yes
# 480	Active	Active	Yes
# 481	Active	Active	Yes
# 482	Inactive	Active	No
# 483	Active	Active	Yes
# 484	Inactive	Active	No
# 485	Active	Active	Yes
# 486	Inactive	Active	No
# 487	Inactive	Active	No
# 488	Inactive	Active	No
# 489	Inactive	Inactive	Yes
# 490	Active	Active	Yes
# 491	Inactive	Active	No
# 492	Inactive	Active	No
# 493	Inactive	Inactive	Yes
# 494	Inactive	Active	No
# 495	Active	Active	Yes
# 496	Active	Active	Yes
# 497	Active	Active	Yes
# 498	Active	Active	Yes
# 499	Active	Active	Yes
# 500	Inactive	Active	No
# 501	Inactive	Active	No
# 502	Inactive	Inactive	Yes
# 503	Inactive	Inactive	Yes
# 504	Inactive	Active	No
# 505	Inactive	Active	No
# 506	Active	Active	Yes
# 507	Inactive	Active	No
# 508	Inactive	Active	No
# 509	Inactive	Active	No
# 510	Active	Active	Yes
# 511	Active	Active	Yes
# 512	Active	Active	Yes
# 513	Inactive	Active	No
# 514	Active	Active	Yes
# 515	Active	Inactive	No
# 516	Active	Active	Yes
# 517	Active	Active	Yes
# 518	Active	Active	Yes
# 519	Active	Active	Yes
# 520	Inactive	Active	No
# 521	Inactive	Active	No
# 522	Inactive	Active	No
# 523	Inactive	Active	No
# 524	Inactive	Active	No
# 525	Active	Active	Yes
# 526	Inactive	Active	No
# 527	Inactive	Active	No
# 528	Inactive	Active	No
# 529	Active	Active	Yes
# 530	Active	Active	Yes
# 531	Active	Active	Yes
# 532	Inactive	Active	No
# 533	Inactive	Active	No
# 534	Active	Active	Yes
# 535	Inactive	Active	No
# 536	Inactive	Active	No
# 537	Active	Active	Yes
# 538	Inactive	Active	No
# 539	Active	Active	Yes
# 540	Inactive	Active	No
# 541	Active	Active	Yes
# 542	Active	Active	Yes
# 543	Active	Inactive	No
# 544	Active	Active	Yes
# 545	Inactive	Active	No
# 546	Inactive	Active	No
# 547	Active	Active	Yes
# 548	Active	Active	Yes
# 549	Inactive	Active	No
# 550	Active	Active	Yes
# 551	Active	Active	Yes
# 552	Inactive	Active	No
# 553	Inactive	Active	No
# 554	Inactive	Active	No
# 555	Active	Active	Yes
# 556	Inactive	Active	No
# 557	Active	Active	Yes
# 558	Active	Active	Yes
# 559	Active	Active	Yes
# 560	Active	Active	Yes
# 561	Active	Active	Yes
# 562	Active	Active	Yes
# 563	Active	Active	Yes
# 564	Active	Active	Yes
# 565	Inactive	Active	No
# 566	Inactive	Inactive	Yes
# 567	Active	Active	Yes
# 568	Inactive	Active	No
# 569	Active	Inactive	No
# 570	Active	Active	Yes
# 571	Active	Active	Yes
# 572	Inactive	Inactive	Yes
# 573	Inactive	Active	No
# 574	Active	Active	Yes
# 575	Active	Active	Yes
# 576	Inactive	Active	No
# 577	Active	Active	Yes
# 578	Active	Inactive	No
# 579	Inactive	Active	No
# 580	Active	Active	Yes
# 581	Active	Active	Yes
# 582	Active	Active	Yes
# 583	Active	Active	Yes
# 584	Inactive	Active	No
# 585	Active	Active	Yes
# 586	Inactive	Active	No
# 587	Active	Active	Yes
# 588	Active	Active	Yes
# 589	Active	Active	Yes
# 590	Inactive	Active	No
# 591	Inactive	Inactive	Yes
# 592	Active	Active	Yes
# 593	Active	Active	Yes
# 594	Inactive	Active	No
# 595	Inactive	Inactive	Yes
# 596	Inactive	Active	No
# 597	Active	Active	Yes
# 598	Active	Active	Yes
# 599	Active	Active	Yes
# 600	Inactive	Active	No
# 601	Inactive	Active	No
# 602	Active	Active	Yes
# 603	Active	Active	Yes
# 604	Active	Active	Yes
# 605	Active	Active	Yes
# 606	Active	Active	Yes
# 607	Inactive	Active	No
# 608	Inactive	Active	No
# 609	Inactive	Active	No
# 610	Inactive	Active	No
# 611	Active	Active	Yes
# 612	Inactive	Active	No
# 613	Inactive	Active	No
# 614	Inactive	Active	No
# 615	Active	Active	Yes
# 616	Inactive	Active	No
# 617	Active	Active	Yes
# 618	Active	Active	Yes
# 619	Inactive	Inactive	Yes
# 620	Inactive	Active	No
# 621	Inactive	Active	No
# 622	Inactive	Active	No
# 623	Active	Active	Yes
# 624	Inactive	Active	No
# 625	Active	Active	Yes
# 626	Inactive	Active	No
# 627	Inactive	Active	No
# 628	Active	Active	Yes
# 629	Active	Active	Yes
# 630	Active	Active	Yes
# 631	Inactive	Active	No
# 632	Active	Active	Yes
# 633	Inactive	Active	No
# 634	Active	Active	Yes
# 635	Inactive	Active	No
# 636	Inactive	Active	No
# 637	Inactive	Active	No
# 638	Inactive	Active	No
# 639	Active	Active	Yes
# 640	Inactive	Active	No
# 641	Inactive	Active	No
# 642	Inactive	Active	No
# 643	Active	Active	Yes
# 644	Inactive	Active	No
# 645	Inactive	Active	No
# 646	Active	Active	Yes
# 647	Active	Active	Yes
# 648	Inactive	Active	No
# 649	Inactive	Active	No
# 650	Inactive	Active	No
# 651	Active	Active	Yes
# 652	Active	Inactive	No
# 653	Inactive	Active	No
# 654	Inactive	Active	No
# 655	Active	Active	Yes
# 656	Active	Active	Yes
# 657	Active	Inactive	No
# 658	Active	Active	Yes
# 659	Inactive	Inactive	Yes
# 660	Inactive	Inactive	Yes
# 661	Inactive	Active	No
# 662	Active	Active	Yes
# 663	Active	Active	Yes
# 664	Inactive	Inactive	Yes
# 665	Active	Active	Yes
# 666	Active	Active	Yes
# 667	Inactive	Active	No
# 668	Active	Active	Yes
# 669	Inactive	Active	No
# 670	Active	Active	Yes
# 671	Inactive	Active	No
# 672	Active	Inactive	No
# 673	Inactive	Active	No
# 674	Active	Active	Yes
# 675	Active	Inactive	No
# 676	Active	Active	Yes
# 677	Active	Active	Yes
# 678	Inactive	Active	No
# 679	Active	Active	Yes
# 680	Inactive	Inactive	Yes
# 681	Inactive	Active	No
# 682	Active	Active	Yes
# 683	Active	Active	Yes
# 684	Inactive	Active	No
# 685	Active	Active	Yes
# 686	Inactive	Active	No
# 687	Inactive	Active	No
# 688	Active	Active	Yes
# 689	Active	Active	Yes
# 690	Inactive	Active	No
# 691	Active	Active	Yes
# 692	Active	Active	Yes
# 693	Inactive	Active	No
# 694	Active	Active	Yes
# 695	Inactive	Active	No
# 696	Active	Active	Yes
# 697	Inactive	Inactive	Yes
# 698	Active	Active	Yes
# 699	Active	Active	Yes
# 700	Active	Active	Yes
# 701	Active	Active	Yes
# 702	Inactive	Active	No
# 703	Inactive	Active	No
# 704	Active	Active	Yes
# 705	Inactive	Active	No
# 706	Active	Active	Yes
# 707	Inactive	Active	No
# 708	Inactive	Active	No
# 709	Active	Active	Yes
# 710	Active	Active	Yes
# 711	Active	Active	Yes
# 712	Active	Active	Yes
# 713	Inactive	Active	No
# 714	Inactive	Active	No
# 715	Active	Active	Yes
# 716	Inactive	Active	No
# 717	Active	Active	Yes
# 718	Inactive	Active	No
# 719	Inactive	Active	No
# 720	Active	Active	Yes
# 721	Active	Active	Yes
# 722	Active	Active	Yes
# 723	Active	Active	Yes
# 724	Inactive	Active	No
# 725	Inactive	Inactive	Yes
# 726	Active	Active	Yes
# 727	Inactive	Active	No
# 728	Active	Active	Yes
# 729	Inactive	Active	No
# 730	Active	Active	Yes
# 731	Inactive	Active	No
# 732	Active	Active	Yes
# 733	Inactive	Active	No
# 734	Inactive	Inactive	Yes
# 735	Active	Active	Yes
# 736	Inactive	Inactive	Yes
# 737	Inactive	Active	No
# 738	Active	Active	Yes
# 739	Active	Inactive	No
# 740	Active	Active	Yes
# 741	Active	Active	Yes
# 742	Inactive	Active	No
# 743	Inactive	Active	No
# 744	Active	Active	Yes
# 745	Active	Active	Yes
# 746	Active	Active	Yes
# 747	Inactive	Active	No
# 748	Inactive	Active	No
# 749	Active	Active	Yes
# 750	Active	Active	Yes
# 751	Inactive	Active	No
# 752	Inactive	Active	No
# 753	Inactive	Active	No
# 754	Active	Active	Yes
# 755	Inactive	Active	No
# 756	Active	Active	Yes
# 757	Inactive	Active	No
# 758	Active	Active	Yes
# 759	Active	Active	Yes
# 760	Active	Active	Yes
# 761	Active	Active	Yes
# 762	Active	Active	Yes
# 763	Inactive	Inactive	Yes
# 764	Active	Active	Yes
# 765	Active	Active	Yes
# 766	Inactive	Active	No
# 767	Active	Active	Yes
# 768	Inactive	Active	No
# 769	Active	Active	Yes
# 770	Active	Active	Yes
# 771	Active	Active	Yes
# 772	Active	Active	Yes
# 773	Inactive	Inactive	Yes
# 774	Active	Active	Yes
# 775	Inactive	Active	No
# 776	Inactive	Active	No
# 777	Inactive	Active	No
# 778	Inactive	Inactive	Yes
# 779	Active	Active	Yes
# 780	Active	Active	Yes
# 781	Inactive	Active	No
# 782	Active	Active	Yes
# 783	Inactive	Inactive	Yes
# 784	Inactive	Active	No
# 785	Inactive	Active	No
# 786	Active	Active	Yes
# 787	Inactive	Active	No
# 788	Active	Inactive	No
# 789	Active	Active	Yes
# 790	Active	Active	Yes
# 791	Active	Active	Yes
# 792	Active	Active	Yes
# 793	Active	Active	Yes
# 794	Inactive	Active	No
# 795	Active	Active	Yes
# 796	Active	Active	Yes
# 797	Active	Active	Yes
# 798	Active	Active	Yes
# 799	Inactive	Inactive	Yes
# 800	Inactive	Active	No
# 801	Inactive	Active	No
# 802	Active	Active	Yes
# 803	Active	Active	Yes
# 804	Active	Active	Yes
# 805	Inactive	Active	No
# 806	Inactive	Inactive	Yes
# 807	Active	Active	Yes
# 808	Inactive	Active	No
# 809	Active	Active	Yes
# 810	Active	Active	Yes
# 811	Active	Active	Yes
# 812	Active	Active	Yes
# 813	Inactive	Active	No
# 814	Active	Active	Yes
# 815	Active	Active	Yes
# 816	Inactive	Active	No
# 817	Inactive	Active	No
# 818	Active	Active	Yes
# 819	Active	Inactive	No
# 820	Active	Active	Yes
# 821	Inactive	Active	No
# 822	Inactive	Active	No
# 823	Active	Active	Yes
# 824	Inactive	Inactive	Yes
# 825	Active	Active	Yes
# 826	Active	Active	Yes
# 827	Inactive	Active	No
# 828	Inactive	Active	No
# 829	Inactive	Active	No
# 830	Active	Active	Yes
# 831	Active	Active	Yes
# 832	Active	Active	Yes
# 833	Inactive	Active	No
# 834	Active	Active	Yes
# 835	Inactive	Active	No
# 836	Inactive	Active	No
# 837	Active	Active	Yes
# 838	Inactive	Inactive	Yes
# 839	Active	Active	Yes
# 840	Inactive	Active	No
# 841	Active	Inactive	No
# 842	Active	Active	Yes
# 843	Active	Active	Yes
# 844	Inactive	Active	No
# 845	Inactive	Inactive	Yes
# 846	Inactive	Active	No
# 847	Active	Active	Yes
# 848	Inactive	Inactive	Yes
# 849	Active	Active	Yes
# 850	Active	Active	Yes
# 851	Inactive	Active	No
# 852	Inactive	Active	No
# 853	Inactive	Active	No
# 854	Inactive	Active	No
# 855	Active	Active	Yes
# 856	Active	Active	Yes
# 857	Active	Active	Yes
# 858	Active	Active	Yes
# 859	Inactive	Active	No
# 860	Inactive	Active	No
# 861	Inactive	Active	No
# 862	Active	Active	Yes
# 863	Inactive	Inactive	Yes
# 864	Inactive	Inactive	Yes
# 865	Active	Active	Yes
# 866	Inactive	Active	No
# 867	Inactive	Active	No
# 868	Active	Active	Yes
# 869	Active	Active	Yes
# 870	Active	Active	Yes
# 871	Active	Active	Yes
# 872	Active	Active	Yes
# 873	Inactive	Active	No
# 874	Inactive	Active	No
# 875	Active	Active	Yes
# 876	Inactive	Inactive	Yes
# 877	Inactive	Active	No
# 878	Inactive	Active	No
# 879	Inactive	Active	No
# 880	Inactive	Active	No
# 881	Inactive	Inactive	Yes
# 882	Active	Active	Yes
# 883	Active	Active	Yes
# 884	Active	Active	Yes
# 885	Active	Active	Yes
# 886	Inactive	Active	No
# 887	Inactive	Inactive	Yes
# 888	Active	Active	Yes
# 889	Inactive	Active	No
# 890	Inactive	Active	No
# 891	Inactive	Active	No
# 892	Active	Active	Yes
# 893	Active	Active	Yes
# 894	Active	Active	Yes
# 895	Active	Active	Yes
# 896	Inactive	Active	No
# 897	Active	Active	Yes
# 898	Inactive	Active	No
# 899	Active	Active	Yes
# 900	Inactive	Active	No
# 901	Active	Inactive	No
# 902	Active	Active	Yes
# 903	Inactive	Active	No
# 904	Inactive	Inactive	Yes
# 905	Active	Active	Yes
# 906	Inactive	Active	No
# 907	Active	Active	Yes
# 908	Inactive	Active	No
# 909	Active	Inactive	No
# 910	Inactive	Active	No
# 911	Active	Active	Yes
# 912	Active	Active	Yes
# 913	Inactive	Active	No
# 914	Active	Active	Yes
# 915	Active	Active	Yes
# 916	Inactive	Active	No
# 917	Active	Active	Yes
# 918	Inactive	Inactive	Yes
# 919	Inactive	Inactive	Yes
# 920	Active	Active	Yes
# 921	Inactive	Inactive	Yes
# 922	Active	Inactive	No
# 923	Inactive	Active	No
# 924	Active	Active	Yes
# 925	Active	Active	Yes
# 926	Inactive	Active	No
# 927	Active	Active	Yes
# 928	Inactive	Active	No
# 929	Active	Active	Yes
# 930	Inactive	Active	No
# 931	Inactive	Active	No
# 932	Active	Active	Yes
# 933	Inactive	Active	No
# 934	Active	Active	Yes
# 935	Active	Active	Yes
# 936	Inactive	Active	No
# 937	Inactive	Active	No
# 938	Inactive	Inactive	Yes
# 939	Inactive	Active	No
# 940	Active	Active	Yes
# 941	Inactive	Inactive	Yes
# 942	Active	Active	Yes
# 943	Inactive	Active	No
# 944	Active	Active	Yes
# 945	Active	Active	Yes
# 946	Active	Active	Yes
# 947	Active	Active	Yes
# 948	Inactive	Inactive	Yes
# 949	Inactive	Inactive	Yes
# 950	Active	Active	Yes
# 951	Active	Active	Yes
# 952	Active	Active	Yes
# 953	Inactive	Active	No
# 954	Active	Active	Yes
# 955	Active	Active	Yes
# 956	Active	Active	Yes
# 957	Active	Active	Yes
# 958	Active	Active	Yes
# 959	Inactive	Active	No
# 960	Active	Active	Yes
# 961	Inactive	Active	No
# 962	Inactive	Inactive	Yes
# 963	Inactive	Active	No
# 964	Inactive	Active	No
# 965	Active	Active	Yes
# 966	Inactive	Active	No
# 967	Active	Active	Yes
# 968	Inactive	Active	No
# 969	Active	Active	Yes
# 970	Active	Active	Yes
# 971	Inactive	Active	No
# 972	Active	Active	Yes
# 973	Active	Active	Yes
# 974	Inactive	Active	No
# 975	Inactive	Active	No
# 976	Active	Active	Yes
# 977	Active	Active	Yes
# 978	Active	Active	Yes
# 979	Inactive	Active	No
# 980	Inactive	Active	No
# 981	Active	Active	Yes
# 982	Inactive	Active	No
# 983	Inactive	Active	No
# 984	Active	Active	Yes
# 985	Active	Active	Yes
# 986	Active	Active	Yes
# 987	Inactive	Active	No
# 988	Inactive	Active	No
# 989	Active	Active	Yes
# 990	Active	Active	Yes
# 991	Inactive	Active	No
# 992	Active	Active	Yes
# 993	Active	Active	Yes
# 994	Active	Active	Yes
# 995	Active	Active	Yes
# 996	Active	Active	Yes
# 997	Inactive	Active	No
# 998	Active	Active	Yes
# 999	Active	Active	Yes
# 1000	Active	Active	Yes
# 1001	Active	Active	Yes
# 1002	Inactive	Active	No
# 1003	Inactive	Active	No
# 1004	Inactive	Active	No
# 1005	Inactive	Active	No
# 1006	Inactive	Active	No
# 1007	Active	Active	Yes
# 1008	Active	Active	Yes
# 1009	Inactive	Active	No
# 1010	Inactive	Active	No
# 1011	Active	Active	Yes
# 1012	Inactive	Active	No
# 1013	Active	Active	Yes
# 1014	Inactive	Active	No
# 1015	Active	Active	Yes
# 1016	Inactive	Active	No
# 1017	Active	Active	Yes
# 1018	Inactive	Active	No
# 1019	Active	Active	Yes
# 1020	Inactive	Inactive	Yes
# 1021	Active	Active	Yes
# 1022	Inactive	Inactive	Yes
# 1023	Inactive	Active	No
# 1024	Inactive	Active	No
# 1025	Inactive	Active	No
# 1026	Active	Active	Yes
# 1027	Active	Active	Yes
# 1028	Active	Active	Yes
# 1029	Active	Active	Yes
# 1030	Active	Active	Yes
# 1031	Inactive	Active	No
# 1032	Active	Active	Yes
# 1033	Active	Active	Yes
# 1034	Active	Active	Yes
# 1035	Active	Active	Yes
# 1036	Inactive	Active	No
# 1037	Inactive	Active	No
# 1038	Active	Active	Yes
# 1039	Active	Active	Yes
# 1040	Active	Active	Yes
# 1041	Inactive	Active	No
# 1042	Active	Active	Yes
# 1043	Inactive	Active	No
# 1044	Active	Active	Yes
# 1045	Inactive	Inactive	Yes
# 1046	Active	Active	Yes
# 1047	Inactive	Active	No
# 1048	Inactive	Active	No
# 1049	Active	Active	Yes
# 1050	Inactive	Active	No
# 1051	Inactive	Active	No
# 1052	Active	Active	Yes
# 1053	Active	Active	Yes
# 1054	Inactive	Inactive	Yes
# 1055	Inactive	Active	No
# 1056	Active	Active	Yes
# 1057	Active	Active	Yes
# 1058	Active	Active	Yes
# 1059	Active	Active	Yes
# 1060	Inactive	Active	No
# 1061	Inactive	Active	No
# 1062	Inactive	Active	No
# 1063	Inactive	Active	No
# 1064	Active	Active	Yes
# 1065	Active	Inactive	No
# 1066	Inactive	Active	No
# 1067	Inactive	Active	No
# 1068	Inactive	Active	No
# 1069	Active	Active	Yes
# 1070	Inactive	Active	No
# 1071	Active	Active	Yes
# 1072	Inactive	Active	No
# 1073	Inactive	Active	No
# 1074	Active	Active	Yes
# 1075	Active	Active	Yes
# 1076	Active	Active	Yes
# 1077	Active	Active	Yes
# 1078	Active	Active	Yes
# 1079	Active	Active	Yes
# 1080	Active	Inactive	No
# 1081	Inactive	Active	No
# 1082	Inactive	Active	No
# 1083	Inactive	Inactive	Yes
# 1084	Active	Active	Yes
# 1085	Active	Active	Yes
# 1086	Inactive	Active	No
# 1087	Inactive	Active	No
# 1088	Inactive	Active	No
# 1089	Active	Active	Yes
# 1090	Inactive	Active	No
# 1091	Active	Active	Yes
# 1092	Active	Active	Yes
# 1093	Inactive	Active	No
# 1094	Inactive	Active	No
# 1095	Active	Active	Yes
# 1096	Inactive	Active	No
# 1097	Active	Active	Yes
# 1098	Active	Active	Yes
# 1099	Active	Active	Yes
# 1100	Inactive	Active	No
# 1101	Inactive	Active	No
# 1102	Inactive	Active	No
# 1103	Inactive	Active	No
# 1104	Active	Active	Yes
# 1105	Active	Active	Yes
# 1106	Inactive	Active	No
# 1107	Inactive	Active	No
# 1108	Active	Active	Yes
# 1109	Inactive	Active	No
# 1110	Inactive	Active	No
# 1111	Active	Active	Yes
# 1112	Active	Active	Yes
# 1113	Inactive	Active	No
# 1114	Active	Active	Yes
# 1115	Active	Active	Yes
# 1116	Active	Active	Yes
# 1117	Active	Active	Yes
# 1118	Inactive	Active	No
# 1119	Active	Active	Yes
# 1120	Inactive	Active	No
# 1121	Active	Active	Yes
# 1122	Active	Active	Yes
# 1123	Inactive	Active	No
# 1124	Active	Active	Yes
# 1125	Active	Active	Yes
# 1126	Active	Active	Yes
# 1127	Active	Active	Yes
# 1128	Active	Active	Yes
# 1129	Inactive	Active	No
# 1130	Active	Active	Yes
# 1131	Active	Active	Yes
# 1132	Inactive	Active	No
# 1133	Active	Active	Yes
# 1134	Active	Active	Yes
# 1135	Active	Active	Yes
# 1136	Active	Active	Yes
# 1137	Active	Active	Yes
# 1138	Inactive	Inactive	Yes
# 1139	Inactive	Active	No
# 1140	Inactive	Active	No
# 1141	Inactive	Active	No
# 1142	Active	Active	Yes
# 1143	Active	Active	Yes
# 1144	Inactive	Active	No
# 1145	Inactive	Active	No
# 1146	Active	Active	Yes
# 1147	Active	Active	Yes
# 1148	Inactive	Inactive	Yes
# 1149	Inactive	Active	No
# 1150	Inactive	Active	No
# 1151	Inactive	Active	No
# 1152	Active	Inactive	No
# 1153	Inactive	Inactive	Yes
# 1154	Active	Active	Yes
# 1155	Active	Inactive	No
# 1156	Inactive	Inactive	Yes
# 1157	Inactive	Inactive	Yes
# 1158	Inactive	Active	No
# 1159	Active	Active	Yes
# 1160	Inactive	Active	No
# 1161	Active	Active	Yes
# 1162	Active	Active	Yes
# 1163	Active	Active	Yes
# 1164	Inactive	Active	No
# 1165	Inactive	Inactive	Yes
# 1166	Active	Active	Yes
# 1167	Inactive	Active	No
# 1168	Inactive	Active	No
# 1169	Active	Active	Yes
# 1170	Inactive	Active	No
# 1171	Active	Active	Yes
# 1172	Inactive	Active	No
# 1173	Active	Active	Yes
# 1174	Inactive	Active	No
# 1175	Active	Active	Yes
# 1176	Inactive	Active	No
# 1177	Inactive	Inactive	Yes
# 1178	Active	Active	Yes
# 1179	Active	Active	Yes
# 1180	Active	Active	Yes
# 1181	Inactive	Active	No
# 1182	Active	Active	Yes
# 1183	Active	Active	Yes
# 1184	Inactive	Inactive	Yes
# 1185	Active	Active	Yes
# 1186	Inactive	Active	No
# 1187	Inactive	Active	No
# 1188	Active	Active	Yes
# 1189	Active	Active	Yes
# 1190	Inactive	Active	No
# 1191	Active	Active	Yes
# 1192	Inactive	Active	No
# 1193	Active	Active	Yes
# 1194	Inactive	Active	No
# 1195	Active	Active	Yes
# 1196	Active	Active	Yes
# 1197	Active	Inactive	No
# 1198	Inactive	Active	No
# 1199	Active	Active	Yes
# 1200	Active	Active	Yes
# 1201	Active	Active	Yes
# 1202	Inactive	Active	No
# 1203	Active	Active	Yes
# 1204	Inactive	Active	No
# 1205	Active	Active	Yes
# 1206	Inactive	Active	No
# 1207	Active	Active	Yes
# 1208	Active	Active	Yes
# 1209	Active	Active	Yes
# 1210	Active	Active	Yes
# 1211	Active	Active	Yes
# 1212	Inactive	Active	No
# 1213	Inactive	Inactive	Yes
# 1214	Inactive	Active	No
# 1215	Active	Inactive	No
# 1216	Active	Active	Yes
# 1217	Inactive	Active	No
# 1218	Inactive	Active	No
# 1219	Active	Active	Yes
# 1220	Active	Active	Yes
# 1221	Active	Active	Yes
# 1222	Active	Active	Yes
# 1223	Active	Active	Yes
# 1224	Inactive	Active	No
# 1225	Inactive	Active	No
# 1226	Active	Active	Yes
# 1227	Active	Active	Yes
# 1228	Active	Active	Yes
# 1229	Active	Active	Yes
# 1230	Active	Active	Yes
# 1231	Active	Active	Yes
# 1232	Inactive	Active	No
# 1233	Inactive	Inactive	Yes
# 1234	Active	Active	Yes
# 1235	Active	Active	Yes
# 1236	Inactive	Active	No
# 1237	Inactive	Active	No
# 1238	Active	Active	Yes
# 1239	Inactive	Active	No
# 1240	Inactive	Active	No
# 1241	Active	Active	Yes
# 1242	Active	Active	Yes
# 1243	Active	Active	Yes
# 1244	Inactive	Active	No
# 1245	Inactive	Inactive	Yes
# 1246	Active	Active	Yes
# 1247	Active	Active	Yes
# 1248	Inactive	Active	No
# 1249	Inactive	Active	No
# 1250	Inactive	Active	No
# 1251	Inactive	Active	No
# 1252	Active	Active	Yes
# 1253	Active	Inactive	No
# 1254	Active	Active	Yes
# 1255	Active	Active	Yes
# 1256	Inactive	Active	No
# 1257	Inactive	Active	No
# 1258	Active	Active	Yes
# 1259	Active	Active	Yes
# 1260	Inactive	Active	No
# 1261	Inactive	Active	No
# 1262	Inactive	Inactive	Yes
# 1263	Inactive	Active	No
# 1264	Active	Active	Yes
# 1265	Inactive	Active	No
# 1266	Active	Active	Yes
# 1267	Inactive	Active	No
# 1268	Inactive	Active	No
# 1269	Inactive	Active	No
# 1270	Inactive	Active	No
# 1271	Active	Active	Yes
# 1272	Active	Active	Yes
# 1273	Inactive	Active	No
#
# Total Correct Predictions: 726/1274
# Accuracy: 0.57
